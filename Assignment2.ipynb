# %% [markdown]
# <a href="https://colab.research.google.com/github/freguti/Homework-ML/blob/Homework_2/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install requirements**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 install 'torch==1.3.1'
# !pip3 install 'torchvision==0.4.2'
# !pip3 install 'Pillow-SIMD'
# !pip3 install 'tqdm'
# !pip3 install --upgrade 'pillow'
# Out:
# Requirement already satisfied: torch==1.3.1 in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.3.1) (1.17.4)
# Requirement already satisfied: torchvision==0.4.2 in /usr/local/lib/python3.6/dist-packages (0.4.2)
# Requirement already satisfied: torch==1.3.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.4.2) (1.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.4.2) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.4.2) (1.17.4)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.4.2) (6.2.1)
# Requirement already satisfied: Pillow-SIMD in /usr/local/lib/python3.6/dist-packages (6.0.0.post0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)
# Requirement already up-to-date: pillow in /usr/local/lib/python3.6/dist-packages (6.2.1)

# %% [markdown]
# **Import libraries**

# %%
import os
import logging
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Subset, DataLoader
from torch.backends import cudnn
import numpy as np
import torchvision
from torchvision import transforms
from torchvision.models import alexnet

from PIL import Image
from tqdm import tqdm

# %% [markdown]
# **Set Arguments**

# %%
DEVICE = 'cuda' # 'cuda' or 'cpu'

NUM_CLASSES = 101 # 101 + 1: There is am extra Background class that should be removed 

BATCH_SIZE = 256     # Higher batch sizes allows for larger learning rates. An empirical heuristic suggests that, when changing
                     # the batch size, learning rate should change by the same factor to have comparable results

LR = 0.05            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 5e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 50      # Total number of training epochs (iterations over dataset)
STEP_SIZE = 20       # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.1          # Multiplicative factor for learning rate step-down

LOG_FREQUENCY = 10

# %% [markdown]
# **Define Data Preprocessing**

# %%
# Define transforms for training phase
train_transform = transforms.Compose([transforms.Resize(256),      # Resizes short size of the PIL image to 256
                                      transforms.CenterCrop(224),  # Crops a central square patch of the image
                                                                   # 224 because torchvision's AlexNet needs a 224x224 input!
                                                                   # Remember this when applying different transformations, otherwise you get an error
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) # Normalizes tensor with mean and standard deviation
])
# Define transforms for the evaluation phase
eval_transform = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))                                    
])

# %%
from torchvision.datasets import VisionDataset

from PIL import Image

import os
import os.path
import sys

TRAIN_PATH = 'Homework2-Caltech101/train.txt'
TEST_PATH = 'Homework2-Caltech101/test.txt'
def pil_loader(path):
    # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        img = Image.open(f)
        return img.convert('RGB')


class Caltech(VisionDataset):
    def __init__(self, root, split='train', transform=None, target_transform=None):
        super(Caltech, self).__init__(root, transform=transform, target_transform=target_transform)
        self.split = split # This defines the split you are going to use
                           # (split files are called 'train.txt' and 'test.txt')
        self.classes,self.cl_idx = self.read_classes()
        self.dataset = self.read()
        return

    def read_classes(self):
      classes = []
      f = open(TEST_PATH)
      for l in f.readlines():
        if(l.strip() != '\n' and l.strip() != '' and l.split('/')[0] != 'BACKGROUND_Google'):
          if(not l.split('/')[0] in classes):
            classes.append(l.split('/')[0])
      cl_idx = {classes[i]: i for i in range(len(classes))}
      return classes,cl_idx


    def read(self):
      fine_dataset = []
      #index_class= []
      fine_dataset.clear()
      if(self.split == 'train'):
        f = open(TRAIN_PATH)
      elif(self.split == 'test'):
        f = open(TEST_PATH)
      else:
        return fine_dataset
      for l in f.readlines():
        if(l.strip() != '\n' and l.strip() != ''):
          index_class = l.split('/')[0]
          if(index_class in self.cl_idx and index_class is not None):
            fine_dataset.append((pil_loader(DATA_DIR + '/'+l.split("\n")[0]),self.cl_idx[index_class])) 
      print('len dataset{}'.format(len(fine_dataset)))
      return fine_dataset#,index_class
    def __getitem__(self, index):
        '''
        __getitem__ should access an element through its index
        Args:
            index (int): Index

        Returns:
            tuple: (sample, target) where target is class_index of the target class.
        '''
        image,label = self.dataset[index]

        # Applies preprocessing when accessing the image
        if self.transform is not None:
            image = self.transform(image)
        return image, label

    def __len__(self):
        '''
        The __len__ method returns the length of the dataset
        It is mandatory, as this is used by several other components
        '''
        length = len(self.dataset) # Provide a way to get the length (number of elements) of the dataset
        return length

# %% [markdown]
# **Prepare Dataset**

# %%
# Clone github repository with data
if not os.path.isdir('./Homework2-Caltech101'):
  # !git clone https://github.com/MachineLearning2020/Homework2-Caltech101.git

DATA_DIR = 'Homework2-Caltech101/101_ObjectCategories'

train_dataset = Caltech(DATA_DIR,'train',train_transform);

test_dataset = Caltech(DATA_DIR,'test',train_transform);

print('Train Dataset: {}'.format(len(train_dataset)))
print('Test Dataset: {}'.format(len(test_dataset)))
# Out:
# Cloning into 'Homework2-Caltech101'...
# remote: Enumerating objects: 9256, done.
# remote: Total 9256 (delta 0), reused 0 (delta 0), pack-reused 9256
# Receiving objects: 100% (9256/9256), 129.48 MiB | 43.90 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Checking out files: 100% (9149/9149), done.
# len dataset5784
# len dataset2893
# Train Dataset: 5784
# Test Dataset: 2893

# %%
train = [idx for idx in range(len(train_dataset)) if idx % 2==0]
val=[i+1 for i in train]

train_dataset=Subset(train_dataset,val)
val_dataset=Subset(train_dataset,train)
print('Training split: {}'.format(len(train_dataset)))
print('Validation split: {}'.format(len(val_dataset)))
# Out:
# Training split: 2892
# Validation split: 2892

# %% [markdown]
# **Prepare Dataloaders**

# %%
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
validation_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# %% [markdown]
# **Prepare Network**

# %%
net = alexnet() # Loading AlexNet model

# AlexNet has 1000 output neurons, corresponding to the 1000 ImageNet's classes
# We need 101 outputs for Caltech-101
net.classifier[6] = nn.Linear(4096, NUM_CLASSES) # nn.Linear in pytorch is a fully connected layer
                                                 # The convolutional layer is nn.Conv2d

# We just changed the last layer of AlexNet with a new fully connected layer with 101 outputs
# It is mandatory to study torchvision.models.alexnet source code

# %% [markdown]
# **Prepare Training**

# %%
# Define loss function
criterion = nn.CrossEntropyLoss() # for classification, we use Cross Entropy

# Choose parameters to optimize
# To access a different set of parameters, you have to access submodules of AlexNet
# (nn.Module objects, like AlexNet, implement the Composite Pattern)
# e.g.: parameters of the fully connected layers: net.classifier.parameters()
# e.g.: parameters of the convolutional layers: look at alexnet's source code ;) 
parameters_to_optimize = net.parameters() # In this case we optimize over all the parameters of AlexNet

# Define optimizer
# An optimizer updates the weights based on loss
# We use SGD with momentum
optimizer = optim.SGD(parameters_to_optimize, lr=LR, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# Define scheduler
# A scheduler dynamically changes learning rate
# The most common schedule is the step(-down), which multiplies learning rate by gamma every STEP_SIZE epochs
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=STEP_SIZE, gamma=GAMMA)

# %% [markdown]
# **UTILITIES**

# %%
import copy
def evaluate(model,test_dataset,test_dataloder):
  model = model.to(DEVICE) # this will bring the network to GPU if DEVICE is cuda
  cudnn.benchmark # Calling this optimizes runtime
  model.train(False) # Set Network to evaluation mode
  accuracy=0
  running_corrects = 0
  for images, labels in test_dataloader:
    images = images.to(DEVICE)
    labels = labels.to(DEVICE)
    # Forward Pass
    outputs = model(images)
    # Get predictions
    _, preds = torch.max(outputs.data, 1)
    # Update Corrects
    running_corrects += torch.sum(preds == labels.data).data.item()
  # Calculate Accuracy
  accuracy = running_corrects / float(len(test_dataset))
  print('\t[Validation Accuracy]: {}'.format(accuracy))

  
  return accuracy

def train_and_validate(n_epoch,model,train_dataloader,val_dataset,val_dataloader,optimizer,criterion,scheduler):
  '''
  train the model and validate it on each epoch, 
  return the model with best score on validation set
  '''
  model = model.to(DEVICE) # this will bring the network to GPU if DEVICE is cuda
  current_step = 0
  best_model={'accuracy':0}
  accuracies=[]
  loss_=[]
  # Start iterating over the epochs
  
  for epoch in range(n_epoch):
    medium_loss=0
    count_step=0
    print('Starting epoch {}/{}, LR = {}'.format(epoch+1, n_epoch, scheduler.get_lr()))
    # Iterate over the dataset
    for images, labels in train_dataloader:
      # Bring data over the device of choice
      images = images.to(DEVICE)
      labels = labels.to(DEVICE)
      model.train() # Sets module in training mode
      # PyTorch, by default, accumulates gradients after each backward pass
      # We need to manually set the gradients to zero before starting a new iteration
      optimizer.zero_grad() # Zero-ing the gradients
      # Forward pass to the network
      outputs = model(images)
      # Compute loss based on output and ground truth
      loss = criterion(outputs, labels)

      medium_loss+=loss.item()
      count_step+=1
      # Compute gradients for each layer and update weights
      loss.backward()  # backward pass: computes gradients
      optimizer.step() # update weights based on accumulated gradients
      current_step += 1
    medium_loss=medium_loss/count_step
    loss_.append(medium_loss)
    print('--------------------------------------------') # evaluate epoch's model on val set and evaluate the medium loss
    print('\t[Medium loss of epoch {}]: {}'.format(epoch+1,medium_loss))
    accuracy=evaluate(model,val_dataset,val_dataloader)
    accuracies.append(accuracy)
    if(accuracy > best_model['accuracy']):
      print('\t\t\t\t[BEST MODEL found!]')
      best_model['accuracy']=copy.deepcopy(accuracy)
      best_model['model']=copy.deepcopy(model)
    print('--------------------------------------------')
    scheduler.step()
  best_model['accuracies']=accuracies

  return best_model

# %% [markdown]
# **TRAIN**

# %%
best_model=train_and_validate(50,net,train_dataloader,val_dataset,validation_dataloader,optimizer,criterion,scheduler)

# %% [markdown]
# **Test**

# %%
net = best_model['model']
net = net.to(DEVICE) # this will bring the network to GPU if DEVICE is cuda
net.train(False) # Set Network to evaluation mode

accuracy=evaluate(net,test_dataset,test_dataloader)

# %% [markdown]
# **TRANSFER LEARNING**

# %%
#change the normalization, ImageNet mean and standard deviation
normalize = transforms.Normalize(mean= [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
LRs = [0.01,0.001,0.0001]
EPOCHs = [50,70,20]
STEP_SIZEs = [20,30,5]
GAMMAs = [0.1,0.05,0.2]
BATCH_SIZEs = [256,256,26]
for lr,epoch,step,gamma,index_for in zip(LRs,EPOCHs,STEP_SIZEs,GAMMAs,[0,1,2]):
  trained_net = alexnet(pretrained=True)
  train_transform = transforms.Compose([transforms.Resize(256),      # Resizes short size of the PIL image to 256
                                        transforms.CenterCrop(224),  # Crops a central square patch of the image
                                                                    # 224 because torchvision's AlexNet needs a 224x224 input!
                                                                    # Remember this when applying different transformations, otherwise you get an error
                                        transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                        normalize])
  # Define transforms for the evaluation phase
  eval_transform = transforms.Compose([transforms.Resize(256),
                                        transforms.CenterCrop(224),
                                        transforms.ToTensor(),
                                        normalize])   
  train_dataset = Caltech(DATA_DIR,'train',train_transform);

  test_dataset = Caltech(DATA_DIR,'test',eval_transform);

  train = [idx for idx in range(len(train_dataset)) if idx % 2==0]
  val=[i+1 for i in train]

  train_dataset=Subset(train_dataset,val)
  val_dataset=Subset(train_dataset,train)
  print('Training split: {}'.format(len(train_dataset)))
  print('Validation split: {}'.format(len(val_dataset)))

  trained_net.classifier[6] = nn.Linear(4096, NUM_CLASSES) # nn.Linear in pytorch is a fully connected layer
                                                  # The convolutional layer is nn.Conv2d

  t_criterion = nn.CrossEntropyLoss()


  train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
  test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
  validation_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

  parameters_to_optimize = trained_net.parameters()
  optimizer = optim.SGD(parameters_to_optimize, lr=lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
  scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step, gamma=gamma)
  best_model[index_for]=train_and_validate(epoch,trained_net,train_dataloader,val_dataset,validation_dataloader,optimizer,criterion,scheduler)
  
  print("LR = {}, Number of epochs = {}, Step size = {}, Gamma = {}\n Best accuracy = {}".format(lr,epoch,step,gamma,max(best_model[index_for]["accuracies"])))

'''
 LR = 0.01, Number of epochs = 50, Step size = 20, Gamma = 0.1
 Best accuracy = 0.8509681881051175

 LR = 0.001, Number of epochs = 70, Step size = 30, Gamma = 0.05
 Best accuracy = 0.83298755186722

 LR = 0.0001, Number of epochs = 20, Step size = 5, Gamma = 0.2
 Best accuracy = 0.3558091286307054
 '''

# %%
max_acc = 0
for index_for in [0,1,2]:
  print("LR = {}, Number of epochs = {}, Step size = {}, Gamma = {}\nBest accuracy = {}\n".format(LRs[index_for],EPOCHs[index_for],STEP_SIZEs[index_for],GAMMAs[index_for],max(best_model[index_for]["accuracies"])))
  accuracy=evaluate(best_model[index_for]["model"],test_dataset,test_dataloader)
  if(accuracy > max_acc):
    max_acc = accuracy
    max_lr = LRs[index_for]
    max_epoch = EPOCHs[index_for]
    max_step = STEP_SIZEs[index_for]
    max_gamma = GAMMAs[index_for]
# best params: LR = 0.005, Number of epochs = 50, Step size = 20, Gamma = 0.1
# Best accuracy = 0.8509681881051175
# Test accuracy = 0.8506740407881093

# %%
max_lr = 0.01
max_epoch = 50
max_step = 20
max_gamma = 0.1

# %%
#fully connected layer net.classifier.parameters()
#convolutional layer net.features.parameters()
normalize = transforms.Normalize(mean= [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
fully_net = alexnet(pretrained=True)
conv_net = alexnet(pretrained=True)
train_transform = transforms.Compose([transforms.Resize(256),      # Resizes short size of the PIL image to 256
                                      transforms.CenterCrop(224),  # Crops a central square patch of the image
                                                                  # 224 because torchvision's AlexNet needs a 224x224 input!
                                                                  # Remember this when applying different transformations, otherwise you get an error
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      normalize])
# Define transforms for the evaluation phase
eval_transform = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      normalize])   
train_dataset = Caltech(DATA_DIR,'train',train_transform);

test_dataset = Caltech(DATA_DIR,'test',eval_transform);

train = [idx for idx in range(len(train_dataset)) if idx % 2==0]
val=[i+1 for i in train]

train_dataset=Subset(train_dataset,val)
val_dataset=Subset(train_dataset,train)
print('Training split: {}'.format(len(train_dataset)))
print('Validation split: {}'.format(len(val_dataset)))

fully_net.classifier[6] = nn.Linear(4096, NUM_CLASSES) 
conv_net.classifier[6] = nn.Linear(4096, NUM_CLASSES) 
t_criterion = nn.CrossEntropyLoss()


train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
validation_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
parameters_to_optimize = fully_net.classifier.parameters()
parameters_to_optimize_conv = conv_net.features.parameters()

for param,i,net in zip([parameters_to_optimize_conv,parameters_to_optimize],["convolutional layer","fully connected layer"],[conv_net,fully_net]):
  optimizer = optim.SGD(param, lr=max_lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
  scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=max_step, gamma=max_gamma)
  best_model=train_and_validate(max_epoch,net,train_dataloader,val_dataset,validation_dataloader,optimizer,criterion,scheduler)
  print("type = {} ,LR = {}, Number of epochs = {}, Step size = {}, Gamma = {}\n Best accuracy = {}\n".format(i,max_lr,max_epoch,max_step,max_gamma,max(best_model["accuracies"])))
  accuracy = evaluate(best_model["model"],test_dataset,test_dataloader)
  print("test accuracy = {}\n".format(accuracy))
# CONVOLUTIONAL: Best accuracy = 0.5615491009681881 test = 0.5613549948150709

# FULLY CONNECTED: Best accuracy = 0.8592669432918395 test = 0.8589699274109921
# Out:
# len dataset5784
# len dataset2893
# Training split: 2892
# Validation split: 2892
# Starting epoch 1/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 1]: 4.576128699562767
# 	[Validation Accuracy]: 0.165283540802213
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 2/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 2]: 3.9858145713806152
# 	[Validation Accuracy]: 0.23686030428769017
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 3/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 3]: 3.5384666702964087
# 	[Validation Accuracy]: 0.28734439834024894
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 4/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 4]: 3.35447604005987
# 	[Validation Accuracy]: 0.3112033195020747
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 5/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 5]: 3.20004846832969
# 	[Validation Accuracy]: 0.35096818810511754
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 6/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 6]: 3.0626365054737437
# 	[Validation Accuracy]: 0.36929460580912865
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 7/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 7]: 2.9445661414753306
# 	[Validation Accuracy]: 0.3969571230982019
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 8/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 8]: 2.7921157750216397
# 	[Validation Accuracy]: 0.42047026279391425
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 9/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 9]: 2.6807741685347124
# 	[Validation Accuracy]: 0.43291839557399725
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 10/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 10]: 2.5894335399974477
# 	[Validation Accuracy]: 0.4315352697095436
# --------------------------------------------
# Starting epoch 11/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 11]: 2.5400698618455366
# 	[Validation Accuracy]: 0.43533886583679116
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 12/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 12]: 2.4318206960504707
# 	[Validation Accuracy]: 0.45228215767634855
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 13/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 13]: 2.3325908184051514
# 	[Validation Accuracy]: 0.47199170124481327
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 14/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 14]: 2.234954097054221
# 	[Validation Accuracy]: 0.4733748271092669
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 15/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 15]: 2.1710012284192173
# 	[Validation Accuracy]: 0.47925311203319504
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 16/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 16]: 2.0904253829609263
# 	[Validation Accuracy]: 0.5038035961272476
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 17/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 17]: 2.02155018936504
# 	[Validation Accuracy]: 0.5076071922544951
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 18/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 18]: 1.9307268424467607
# 	[Validation Accuracy]: 0.5024204702627939
# --------------------------------------------
# Starting epoch 19/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 19]: 1.8483926491303877
# 	[Validation Accuracy]: 0.5117565698478561
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 20/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 20]: 1.795680132779208
# 	[Validation Accuracy]: 0.520746887966805
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 21/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 21]: 1.6649422320452603
# 	[Validation Accuracy]: 0.5359612724757953
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 22/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 22]: 1.5412918545983054
# 	[Validation Accuracy]: 0.5352697095435685
# --------------------------------------------
# Starting epoch 23/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 23]: 1.550189039923928
# 	[Validation Accuracy]: 0.5442600276625172
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 24/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 24]: 1.5030095468867908
# 	[Validation Accuracy]: 0.5484094052558783
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 25/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 25]: 1.468099377372048
# 	[Validation Accuracy]: 0.5466804979253111
# --------------------------------------------
# Starting epoch 26/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 26]: 1.4446966322985562
# 	[Validation Accuracy]: 0.5501383125864454
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 27/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 27]: 1.4452385035428135
# 	[Validation Accuracy]: 0.5466804979253111
# --------------------------------------------
# Starting epoch 28/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 28]: 1.4220642284913496
# 	[Validation Accuracy]: 0.5439142461964038
# --------------------------------------------
# Starting epoch 29/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 29]: 1.4278062256899746
# 	[Validation Accuracy]: 0.5525587828492393
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 30/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 30]: 1.386548475785689
# 	[Validation Accuracy]: 0.5508298755186722
# --------------------------------------------
# Starting epoch 31/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 31]: 1.3799548149108887
# 	[Validation Accuracy]: 0.5511756569847857
# --------------------------------------------
# Starting epoch 32/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 32]: 1.3487142324447632
# 	[Validation Accuracy]: 0.5480636237897649
# --------------------------------------------
# Starting epoch 33/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 33]: 1.353726094419306
# 	[Validation Accuracy]: 0.5532503457814661
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 34/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 34]: 1.3548572822050615
# 	[Validation Accuracy]: 0.5525587828492393
# --------------------------------------------
# Starting epoch 35/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 35]: 1.3264000849290327
# 	[Validation Accuracy]: 0.5542876901798064
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 36/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 36]: 1.340475006537004
# 	[Validation Accuracy]: 0.5584370677731674
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 37/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 37]: 1.3315511508421465
# 	[Validation Accuracy]: 0.5577455048409405
# --------------------------------------------
# Starting epoch 38/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 38]: 1.2862583832307295
# 	[Validation Accuracy]: 0.553941908713693
# --------------------------------------------
# Starting epoch 39/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 39]: 1.2984718734567815
# 	[Validation Accuracy]: 0.5573997233748271
# --------------------------------------------
# Starting epoch 40/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 40]: 1.2878377762707798
# 	[Validation Accuracy]: 0.5587828492392808
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 41/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 41]: 1.2636030370538884
# 	[Validation Accuracy]: 0.5584370677731674
# --------------------------------------------
# Starting epoch 42/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 42]: 1.2812355214899236
# 	[Validation Accuracy]: 0.5615491009681881
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 43/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 43]: 1.2233355695551091
# 	[Validation Accuracy]: 0.5615491009681881
# --------------------------------------------
# Starting epoch 44/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 44]: 1.2518219947814941
# 	[Validation Accuracy]: 0.5612033195020747
# --------------------------------------------
# Starting epoch 45/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 45]: 1.2470020922747524
# 	[Validation Accuracy]: 0.5594744121715076
# --------------------------------------------
# Starting epoch 46/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 46]: 1.2490049600601196
# 	[Validation Accuracy]: 0.5608575380359613
# --------------------------------------------
# Starting epoch 47/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 47]: 1.2353369322690098
# 	[Validation Accuracy]: 0.5605117565698479
# --------------------------------------------
# Starting epoch 48/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 48]: 1.246363715692
# 	[Validation Accuracy]: 0.5615491009681881
# --------------------------------------------
# Starting epoch 49/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 49]: 1.2682332559065386
# 	[Validation Accuracy]: 0.5594744121715076
# --------------------------------------------
# Starting epoch 50/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 50]: 1.250380656935952
# 	[Validation Accuracy]: 0.5591286307053942
# --------------------------------------------
# type = convolutional layer ,LR = 0.01, Number of epochs = 50, Step size = 20, Gamma = 0.1
#  Best accuracy = 0.5615491009681881
#
# 	[Validation Accuracy]: 0.5613549948150709
# test accuracy = 0.5613549948150709
#
# Starting epoch 1/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 1]: 2.89410983432423
# 	[Validation Accuracy]: 0.6766943291839558
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 2/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 2]: 0.8077305230227384
# 	[Validation Accuracy]: 0.8042876901798064
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 3/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 3]: 0.32405884022062476
# 	[Validation Accuracy]: 0.8274550484094052
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 4/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 4]: 0.14835587414828214
# 	[Validation Accuracy]: 0.8367911479944675
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 5/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 5]: 0.09256249530748888
# 	[Validation Accuracy]: 0.838865836791148
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 6/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 6]: 0.06590320576320995
# 	[Validation Accuracy]: 0.8392116182572614
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 7/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 7]: 0.05548278784210032
# 	[Validation Accuracy]: 0.848893499308437
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 8/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 8]: 0.035846994343129074
# 	[Validation Accuracy]: 0.8478561549100968
# --------------------------------------------
# Starting epoch 9/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 9]: 0.030387063256718895
# 	[Validation Accuracy]: 0.8502766251728907
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 10/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 10]: 0.0220911768688397
# 	[Validation Accuracy]: 0.853042876901798
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 11/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 11]: 0.024356520480730316
# 	[Validation Accuracy]: 0.8516597510373444
# --------------------------------------------
# Starting epoch 12/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 12]: 0.020155080509456722
# 	[Validation Accuracy]: 0.8533886583679114
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 13/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 13]: 0.01896153153343634
# 	[Validation Accuracy]: 0.8554633471645919
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 14/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 14]: 0.016735133291645485
# 	[Validation Accuracy]: 0.8443983402489627
# --------------------------------------------
# Starting epoch 15/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 15]: 0.01606041971932758
# 	[Validation Accuracy]: 0.857192254495159
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 16/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 16]: 0.015282988548278809
# 	[Validation Accuracy]: 0.8582295988934993
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 17/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 17]: 0.013584366576238112
# 	[Validation Accuracy]: 0.8551175656984785
# --------------------------------------------
# Starting epoch 18/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 18]: 0.011546598747372627
# 	[Validation Accuracy]: 0.8578838174273858
# --------------------------------------------
# Starting epoch 19/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 19]: 0.01011748510328206
# 	[Validation Accuracy]: 0.8544260027662517
# --------------------------------------------
# Starting epoch 20/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 20]: 0.010962283408099955
# 	[Validation Accuracy]: 0.853042876901798
# --------------------------------------------
# Starting epoch 21/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 21]: 0.011474043469537388
# 	[Validation Accuracy]: 0.8544260027662517
# --------------------------------------------
# Starting epoch 22/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 22]: 0.012414070692929354
# 	[Validation Accuracy]: 0.857192254495159
# --------------------------------------------
# Starting epoch 23/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 23]: 0.008991296995769848
# 	[Validation Accuracy]: 0.8589211618257261
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 24/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 24]: 0.010035776617852125
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 25/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 25]: 0.009188707409934565
# 	[Validation Accuracy]: 0.8561549100968188
# --------------------------------------------
# Starting epoch 26/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 26]: 0.008936902338808233
# 	[Validation Accuracy]: 0.8565006915629322
# --------------------------------------------
# Starting epoch 27/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 27]: 0.008739107542417267
# 	[Validation Accuracy]: 0.8558091286307054
# --------------------------------------------
# Starting epoch 28/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 28]: 0.007375423711809245
# 	[Validation Accuracy]: 0.8568464730290456
# --------------------------------------------
# Starting epoch 29/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 29]: 0.009988486766815186
# 	[Validation Accuracy]: 0.8568464730290456
# --------------------------------------------
# Starting epoch 30/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 30]: 0.008977974511005661
# 	[Validation Accuracy]: 0.8565006915629322
# --------------------------------------------
# Starting epoch 31/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 31]: 0.00939834558150985
# 	[Validation Accuracy]: 0.8558091286307054
# --------------------------------------------
# Starting epoch 32/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 32]: 0.00800598683682355
# 	[Validation Accuracy]: 0.8568464730290456
# --------------------------------------------
# Starting epoch 33/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 33]: 0.008336445486003702
# 	[Validation Accuracy]: 0.8568464730290456
# --------------------------------------------
# Starting epoch 34/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 34]: 0.008487884293903004
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 35/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 35]: 0.008017751642248848
# 	[Validation Accuracy]: 0.8582295988934993
# --------------------------------------------
# Starting epoch 36/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 36]: 0.009239411150867289
# 	[Validation Accuracy]: 0.8592669432918395
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 37/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 37]: 0.008607190102338791
# 	[Validation Accuracy]: 0.8589211618257261
# --------------------------------------------
# Starting epoch 38/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 38]: 0.008240942589261314
# 	[Validation Accuracy]: 0.8585753803596127
# --------------------------------------------
# Starting epoch 39/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 39]: 0.007573832842436704
# 	[Validation Accuracy]: 0.8582295988934993
# --------------------------------------------
# Starting epoch 40/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 40]: 0.008945390243421902
# 	[Validation Accuracy]: 0.8578838174273858
# --------------------------------------------
# Starting epoch 41/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 41]: 0.007638210938735442
# 	[Validation Accuracy]: 0.8578838174273858
# --------------------------------------------
# Starting epoch 42/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 42]: 0.008484671061689203
# 	[Validation Accuracy]: 0.8578838174273858
# --------------------------------------------
# Starting epoch 43/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 43]: 0.007769439030777325
# 	[Validation Accuracy]: 0.8578838174273858
# --------------------------------------------
# Starting epoch 44/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 44]: 0.008488233455202797
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 45/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 45]: 0.008987499739636074
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 46/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 46]: 0.00670928880572319
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 47/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 47]: 0.0074453174390576105
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 48/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 48]: 0.007949293675747785
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 49/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 49]: 0.0071140669963576575
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# Starting epoch 50/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 50]: 0.007130574096332897
# 	[Validation Accuracy]: 0.8575380359612724
# --------------------------------------------
# type = fully connected layer ,LR = 0.01, Number of epochs = 50, Step size = 20, Gamma = 0.1
#  Best accuracy = 0.8592669432918395
#
# 	[Validation Accuracy]: 0.8589699274109921
# test accuracy = 0.8589699274109921

# %%
normalize = transforms.Normalize(mean= [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
train_tr1 = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224), 
                                      transforms.RandomHorizontalFlip(1),  
                                      transforms.ToTensor(),
                                      normalize ])

test_tr1 = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.RandomHorizontalFlip(1),
                                      transforms.ToTensor(),
                                      normalize])  

train_tr2 = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224), 
                                      transforms.RandomVerticalFlip(1),  
                                      transforms.ToTensor(),
                                      normalize ])

test_tr2 = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.RandomVerticalFlip(1),
                                      transforms.ToTensor(),
                                      normalize])   

train_tr3 = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224), 
                                      transforms.RandomPerspective(0.5,1,3),  
                                      transforms.ToTensor(),
                                      normalize ])

test_tr3 = transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.RandomPerspective(0.5,1,3),
                                      transforms.ToTensor(),
                                      normalize])    

train_dataset = Caltech(DATA_DIR,'train',train_transform);
test_dataset = Caltech(DATA_DIR,'test',eval_transform);
train_dataset += Caltech(DATA_DIR,'train',train_tr1);
test_dataset += Caltech(DATA_DIR,'test',test_tr1);
train_dataset += Caltech(DATA_DIR,'train',train_tr2);
test_dataset += Caltech(DATA_DIR,'test',test_tr2);
train_dataset += Caltech(DATA_DIR,'train',train_tr3);
test_dataset += Caltech(DATA_DIR,'test',test_tr3);
print(len(test_dataset))
print(len(train_dataset))
# Out:
# len dataset5784
# len dataset2893
# len dataset5784
# len dataset2893
# len dataset5784
# len dataset2893
# len dataset5784
# len dataset2893
# 11572
# 23136

# %%
train = [idx for idx in range(len(train_dataset)) if idx % 2==0]
val=[i+1 for i in train]

train_dataset=Subset(train_dataset,val)
val_dataset=Subset(train_dataset,train)
print('Training split: {}'.format(len(train_dataset)))
print('Validation split: {}'.format(len(val_dataset)))

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
validation_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

net = alexnet(pretrained=True)

net.classifier[6] = nn.Linear(4096, NUM_CLASSES) 
t_criterion = nn.CrossEntropyLoss()

parameters_to_optimize = net.parameters()

optimizer = optim.SGD(parameters_to_optimize, lr=max_lr, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=max_step, gamma=max_gamma)
best_model=train_and_validate(max_epoch,net,train_dataloader,val_dataset,validation_dataloader,optimizer,criterion,scheduler)



# loss: 0.0034390117559168075 train:  0.8150933609958506 test: 0.814898029726927
# Out:
# Training split: 11568
# Validation split: 11568
# Starting epoch 1/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 1]: 1.6204469468858507
# 	[Validation Accuracy]: 0.7519017980636238
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 2/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 2]: 0.3730251845386293
# 	[Validation Accuracy]: 0.7636583679114799
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 3/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 3]: 0.20565384891298083
# 	[Validation Accuracy]: 0.7815525587828492
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 4/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 4]: 0.11086799982521268
# 	[Validation Accuracy]: 0.7799965421853389
# --------------------------------------------
# Starting epoch 5/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 5]: 0.0853577669709921
# 	[Validation Accuracy]: 0.7863070539419087
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 6/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 6]: 0.07817924047509829
# 	[Validation Accuracy]: 0.7929633471645919
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 7/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 7]: 0.05370246147116025
# 	[Validation Accuracy]: 0.7788727524204703
# --------------------------------------------
# Starting epoch 8/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 8]: 0.04646989868746863
# 	[Validation Accuracy]: 0.7940006915629322
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 9/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 9]: 0.04472665290037791
# 	[Validation Accuracy]: 0.7780082987551867
# --------------------------------------------
# Starting epoch 10/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 10]: 0.044644297949141924
# 	[Validation Accuracy]: 0.7933091286307054
# --------------------------------------------
# Starting epoch 11/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 11]: 0.02333028047449059
# 	[Validation Accuracy]: 0.7948651452282157
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 12/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 12]: 0.02453237883746624
# 	[Validation Accuracy]: 0.7879495159059474
# --------------------------------------------
# Starting epoch 13/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 13]: 0.024097744127114615
# 	[Validation Accuracy]: 0.7909751037344398
# --------------------------------------------
# Starting epoch 14/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 14]: 0.02780134015613132
# 	[Validation Accuracy]: 0.7876901798063624
# --------------------------------------------
# Starting epoch 15/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 15]: 0.025385709065530036
# 	[Validation Accuracy]: 0.7914937759336099
# --------------------------------------------
# Starting epoch 16/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 16]: 0.026449795067310333
# 	[Validation Accuracy]: 0.7921853388658368
# --------------------------------------------
# Starting epoch 17/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 17]: 0.02822665216194259
# 	[Validation Accuracy]: 0.7873443983402489
# --------------------------------------------
# Starting epoch 18/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 18]: 0.021376035321089955
# 	[Validation Accuracy]: 0.7893326417704011
# --------------------------------------------
# Starting epoch 19/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 19]: 0.019045376860433155
# 	[Validation Accuracy]: 0.7882952973720608
# --------------------------------------------
# Starting epoch 20/50, LR = [0.01]
# --------------------------------------------
# 	[Medium loss of epoch 20]: 0.019362294839488134
# 	[Validation Accuracy]: 0.7972856154910097
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 21/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 21]: 0.007206218938032786
# 	[Validation Accuracy]: 0.8051521438450899
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 22/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 22]: 0.00600595192776786
# 	[Validation Accuracy]: 0.8070539419087137
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 23/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 23]: 0.005014120704597897
# 	[Validation Accuracy]: 0.8092150760719226
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 24/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 24]: 0.005768000665638182
# 	[Validation Accuracy]: 0.8105982019363762
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 25/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 25]: 0.004738977799812953
# 	[Validation Accuracy]: 0.8133644536652835
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 26/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 26]: 0.004320421566565831
# 	[Validation Accuracy]: 0.8092150760719226
# --------------------------------------------
# Starting epoch 27/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 27]: 0.004444913897249434
# 	[Validation Accuracy]: 0.8105982019363762
# --------------------------------------------
# Starting epoch 28/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 28]: 0.004264047369360924
# 	[Validation Accuracy]: 0.8100795297372061
# --------------------------------------------
# Starting epoch 29/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 29]: 0.003065171216924985
# 	[Validation Accuracy]: 0.8128457814661134
# --------------------------------------------
# Starting epoch 30/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 30]: 0.0043990391823980545
# 	[Validation Accuracy]: 0.8115491009681881
# --------------------------------------------
# Starting epoch 31/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 31]: 0.0034158358971277873
# 	[Validation Accuracy]: 0.8105982019363762
# --------------------------------------------
# Starting epoch 32/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 32]: 0.0027278009388181897
# 	[Validation Accuracy]: 0.8146611341632088
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 33/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 33]: 0.003277429524395201
# 	[Validation Accuracy]: 0.8146611341632088
# --------------------------------------------
# Starting epoch 34/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 34]: 0.0037256182067924074
# 	[Validation Accuracy]: 0.8144017980636238
# --------------------------------------------
# Starting epoch 35/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 35]: 0.002953074665533172
# 	[Validation Accuracy]: 0.8144882434301521
# --------------------------------------------
# Starting epoch 36/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 36]: 0.0036098872621854144
# 	[Validation Accuracy]: 0.8122406639004149
# --------------------------------------------
# Starting epoch 37/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 37]: 0.0039730591078599295
# 	[Validation Accuracy]: 0.8133644536652835
# --------------------------------------------
# Starting epoch 38/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 38]: 0.002046626309553782
# 	[Validation Accuracy]: 0.8113762102351314
# --------------------------------------------
# Starting epoch 39/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 39]: 0.0025064426163832346
# 	[Validation Accuracy]: 0.8132780082987552
# --------------------------------------------
# Starting epoch 40/50, LR = [0.001]
# --------------------------------------------
# 	[Medium loss of epoch 40]: 0.0024017164276705846
# 	[Validation Accuracy]: 0.8135373443983402
# --------------------------------------------
# Starting epoch 41/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 41]: 0.0034390117559168075
# 	[Validation Accuracy]: 0.8150933609958506
# 				[BEST MODEL found!]
# --------------------------------------------
# Starting epoch 42/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 42]: 0.002290339478188091
# 	[Validation Accuracy]: 0.8130186721991701
# --------------------------------------------
# Starting epoch 43/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 43]: 0.0027332435879442426
# 	[Validation Accuracy]: 0.8129322268326418
# --------------------------------------------
# Starting epoch 44/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 44]: 0.00242364216181967
# 	[Validation Accuracy]: 0.8133644536652835
# --------------------------------------------
# Starting epoch 45/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 45]: 0.001661371605263816
# 	[Validation Accuracy]: 0.8131051175656985
# --------------------------------------------
# Starting epoch 46/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 46]: 0.0032744282235701878
# 	[Validation Accuracy]: 0.8124135546334716
# --------------------------------------------
# Starting epoch 47/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 47]: 0.0025032646126217314
# 	[Validation Accuracy]: 0.8128457814661134
# --------------------------------------------
# Starting epoch 48/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 48]: 0.002120502210325665
# 	[Validation Accuracy]: 0.8142289073305671
# --------------------------------------------
# Starting epoch 49/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 49]: 0.002798738910092248
# 	[Validation Accuracy]: 0.8119813278008299
# --------------------------------------------
# Starting epoch 50/50, LR = [0.00010000000000000002]
# --------------------------------------------
# 	[Medium loss of epoch 50]: 0.002334413346317079
# 	[Validation Accuracy]: 0.8132780082987552
# --------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-80742e374842> in <module>()
#      21 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=max_step, gamma=max_gamma)
#      22 best_model=train_and_validate(max_epoch,net,train_dataloader,val_dataset,validation_dataloader,optimizer,criterion,scheduler)
# ---> 23 print("type = {} ,LR = {}, Number of epochs = {}, Step size = {}, Gamma = {}\n Best accuracy = {}\n".format(i,max_lr,max_epoch,max_step,max_gamma,max(best_model["accuracies"])))
#      24 accuracy = evaluate(best_model["model"],test_dataset,test_dataloader)
#      25 print("test accuracy = {}\n".format(accuracy))
#
# NameError: name 'i' is not defined

# %%
accuracy = evaluate(best_model["model"],test_dataset,test_dataloader)
print("test accuracy = {}\n".format(accuracy))
# Out:
# 	[Validation Accuracy]: 0.814898029726927
# test accuracy = 0.814898029726927
